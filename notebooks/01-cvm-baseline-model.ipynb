# %%
# %%time
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # Linear algebra
import pandas as pd # Data processing, CSV file I/O (e.g. pd.read_csv)
import lightgbm as lgb # LightGBM is a gradient boosting framework that uses tree based learning algorithms

from bayes_opt import BayesianOptimization # Pure Python implementation of bayesian global optimization with gaussian processes

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,KFold
from sklearn.preprocessing import StandardScaler


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Wall time: 0 ns

# %%
# %%time
# Define a seed for everything
def seed_everything(seed = 42):
    rn.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
# Out:
# Wall time: 0 ns

# %%
# %%time
# Configure notebook display settings
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', 20) 
pd.set_option('display.max_rows', 50)
# Out:
# Wall time: 0 ns

# %%
# %%time
# Model parameters 
TRAIN_PATH =  '../data/input/train.csv'
TEST_PATH  = '../data/input/test.csv'
train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
# Out:
# Wall time: 4.03 s

# %%
# %%time
train.head()
# Out:
# Wall time: 0 ns
#      RowId  IntersectionId  Latitude  Longitude               EntryStreetName  \
# 0  1920335               0     33.79     -84.43  Marietta Boulevard Northwest
# 1  1920336               0     33.79     -84.43  Marietta Boulevard Northwest
# 2  1920337               0     33.79     -84.43  Marietta Boulevard Northwest
# 3  1920338               0     33.79     -84.43  Marietta Boulevard Northwest
# 4  1920339               0     33.79     -84.43  Marietta Boulevard Northwest
#
#                  ExitStreetName EntryHeading ExitHeading  Hour  Weekend  ...  \
# 0  Marietta Boulevard Northwest           NW          NW     0        0  ...
# 1  Marietta Boulevard Northwest           SE          SE     0        0  ...
# 2  Marietta Boulevard Northwest           NW          NW     1        0  ...
# 3  Marietta Boulevard Northwest           SE          SE     1        0  ...
# 4  Marietta Boulevard Northwest           NW          NW     2        0  ...
#
#    TimeFromFirstStop_p40 TimeFromFirstStop_p50  TimeFromFirstStop_p60  \
# 0                      0                     0                      0
# 1                      0                     0                      0
# 2                      0                     0                      0
# 3                      0                     0                      0
# 4                      0                     0                      0
#
#    TimeFromFirstStop_p80  DistanceToFirstStop_p20  DistanceToFirstStop_p40  \
# 0                      0                     0.00                     0.00
# 1                      0                     0.00                     0.00
# 2                      0                     0.00                     0.00
# 3                      0                     0.00                     0.00
# 4                      0                     0.00                     0.00
#
#    DistanceToFirstStop_p50  DistanceToFirstStop_p60  DistanceToFirstStop_p80  \
# 0                     0.00                     0.00                     0.00
# 1                     0.00                     0.00                     0.00
# 2                     0.00                     0.00                     0.00
# 3                     0.00                     0.00                     0.00
# 4                     0.00                     0.00                     0.00
#
#       City
# 0  Atlanta
# 1  Atlanta
# 2  Atlanta
# 3  Atlanta
# 4  Atlanta
#
# [5 rows x 28 columns]

# %%
# %%time
test.head()
# Out:
# Wall time: 0 ns
#    RowId  IntersectionId  Latitude  Longitude             EntryStreetName  \
# 0      0               1     33.75     -84.39  Peachtree Street Southwest
# 1      1               1     33.75     -84.39  Peachtree Street Southwest
# 2      2               1     33.75     -84.39  Peachtree Street Southwest
# 3      3               1     33.75     -84.39  Peachtree Street Southwest
# 4      4               1     33.75     -84.39  Peachtree Street Southwest
#
#                ExitStreetName EntryHeading ExitHeading  Hour  Weekend  Month  \
# 0   Mitchell Street Southwest           SW          SE     0        0      6
# 1  Peachtree Street Southwest           SW          SW     0        0      6
# 2  Peachtree Street Southwest           NE          NE     1        0      6
# 3  Peachtree Street Southwest           SW          SW     1        0      6
# 4  Peachtree Street Southwest           NE          NE     2        0      6
#
#                                                 Path     City
# 0  Peachtree Street Southwest_SW_Mitchell Street ...  Atlanta
# 1  Peachtree Street Southwest_SW_Peachtree Street...  Atlanta
# 2  Peachtree Street Southwest_NE_Peachtree Street...  Atlanta
# 3  Peachtree Street Southwest_SW_Peachtree Street...  Atlanta
# 4  Peachtree Street Southwest_NE_Peachtree Street...  Atlanta

# %%
# %%time
# Provides a list of the null columns in the dataframe and the quantity
null_columns = train.columns[train.isnull().any()]
train[null_columns].isnull().sum()
# Out:
# Wall time: 217 ms
# EntryStreetName    8189
# ExitStreetName     5534
# dtype: int64

# %%
# %%time
train[['EntryStreetName', 'ExitStreetName', 'Path']].sample(10)
# Out:
# Wall time: 41 ms
#                   EntryStreetName           ExitStreetName  \
# 562823          North 33rd Street   West Montgomery Avenue
# 751349         West Lehigh Avenue       West Lehigh Avenue
# 117081        Boulevard Southeast      Boulevard Northeast
# 24887   Piedmont Avenue Northeast   North Avenue Northeast
# 315508             Charter Street        Commercial Street
# 607143           Baltimore Avenue         Baltimore Avenue
# 55350        Crown Road Southeast     Crown Road Southeast
# 409835    West Ida B. Wells Drive  West Ida B. Wells Drive
# 419123     North Milwaukee Avenue   North Milwaukee Avenue
# 672012               Pratt Street             Pratt Street
#
#                                                      Path
# 562823       North 33rd Street_N_West Montgomery Avenue_E
# 751349          West Lehigh Avenue_E_West Lehigh Avenue_E
# 117081        Boulevard Southeast_N_Boulevard Northeast_N
# 24887   Piedmont Avenue Northeast_N_North Avenue North...
# 315508             Charter Street_NW_Commercial Street_SW
# 607143              Baltimore Avenue_W_Baltimore Avenue_W
# 55350     Crown Road Southeast_SE_Crown Road Southeast_SE
# 409835  West Ida B. Wells Drive_E_West Ida B. Wells Dr...
# 419123  North Milwaukee Avenue_NW_North Milwaukee Aven...
# 672012                    Pratt Street_SE_Pratt Street_SE

# %%
# %%time
entrySummary = train.groupby(['EntryStreetName'])['ExitStreetName'].nunique().reset_index()
exitSummary = train.groupby(['ExitStreetName'])['EntryStreetName'].nunique().reset_index()
# Out:
# Wall time: 331 ms

# %%
# %%time
entrySummary
# Out:
# Wall time: 0 ns
#              EntryStreetName  ExitStreetName
# 0      10th Street Northeast               8
# 1      10th Street Northwest              12
# 2      12th Street Northeast               1
# 3      14th Street Northeast               6
# 4      14th Street Northwest              11
# ...                      ...             ...
# 1702      Worcester Drive NE               1
# 1703  Wylie Street Southeast               2
# 1704  Wyman Street Southeast               2
# 1705       Wynnefield Avenue               4
# 1706       Zinkoff Boulevard               2
#
# [1707 rows x 2 columns]

# %%
# %%time
exitSummary
# Out:
# Wall time: 0 ns
#               ExitStreetName  EntryStreetName
# 0      10th Street Northeast                8
# 1      10th Street Northwest               12
# 2      12th Street Northeast                1
# 3      14th Street Northeast                5
# 4      14th Street Northwest               11
# ...                      ...              ...
# 1688  Wylie Street Southeast                2
# 1689  Wyman Street Southeast                2
# 1690       Wynnefield Avenue                4
# 1691          Wyoming Street                1
# 1692       Zinkoff Boulevard                3
#
# [1693 rows x 2 columns]

# %%
# %%time
# Display the first few rows of the dataset
train.describe()
# Out:
# Wall time: 704 ms
#              RowId  IntersectionId   Latitude  Longitude       Hour  \
# count   857,409.00      857,409.00 857,409.00 857,409.00 857,409.00
# mean  2,349,039.00          836.33      39.66     -77.90      12.43
# std     247,512.80          644.20       2.92       5.98       6.06
# min   1,920,335.00            0.00      33.65     -87.84       0.00
# 25%   2,134,687.00          306.00      39.94     -84.39       8.00
# 50%   2,349,039.00          685.00      39.99     -75.17      13.00
# 75%   2,563,391.00        1,254.00      41.92     -75.08      17.00
# max   2,777,743.00        2,875.00      42.38     -71.02      23.00
#
#          Weekend      Month  TotalTimeStopped_p20  TotalTimeStopped_p40  \
# count 857,409.00 857,409.00            857,409.00            857,409.00
# mean        0.28       9.10                  1.73                  5.36
# std         0.45       1.99                  7.08                 12.86
# min         0.00       1.00                  0.00                  0.00
# 25%         0.00       7.00                  0.00                  0.00
# 50%         0.00       9.00                  0.00                  0.00
# 75%         1.00      11.00                  0.00                  0.00
# max         1.00      12.00                273.00                318.00
#
#        TotalTimeStopped_p50  ...  TimeFromFirstStop_p20  \
# count            857,409.00  ...             857,409.00
# mean                   7.68  ...                   3.13
# std                   15.55  ...                  11.63
# min                    0.00  ...                   0.00
# 25%                    0.00  ...                   0.00
# 50%                    0.00  ...                   0.00
# 75%                   10.00  ...                   0.00
# max                  343.00  ...                 334.00
#
#        TimeFromFirstStop_p40  TimeFromFirstStop_p50  TimeFromFirstStop_p60  \
# count             857,409.00             857,409.00             857,409.00
# mean                    9.05                  12.61                  18.80
# std                    20.12                  23.85                  29.40
# min                     0.00                   0.00                   0.00
# 25%                     0.00                   0.00                   0.00
# 50%                     0.00                   0.00                   0.00
# 75%                     0.00                  22.00                  31.00
# max                   347.00                 355.00                 358.00
#
#        TimeFromFirstStop_p80  DistanceToFirstStop_p20  \
# count             857,409.00               857,409.00
# mean                   34.04                     6.56
# std                    40.62                    28.00
# min                     0.00                     0.00
# 25%                     0.00                     0.00
# 50%                    27.00                     0.00
# 75%                    49.00                     0.00
# max                   359.00                 1,902.70
#
#        DistanceToFirstStop_p40  DistanceToFirstStop_p50  \
# count               857,409.00               857,409.00
# mean                     19.87                    28.26
# std                      56.56                    71.72
# min                       0.00                     0.00
# 25%                       0.00                     0.00
# 50%                       0.00                     0.00
# 75%                       0.00                    52.90
# max                   3,099.50                 3,099.50
#
#        DistanceToFirstStop_p60  DistanceToFirstStop_p80
# count               857,409.00               857,409.00
# mean                     43.27                    81.92
# std                      96.93                   152.68
# min                       0.00                     0.00
# 25%                       0.00                     0.00
# 50%                       0.00                    60.40
# 75%                      64.10                    85.60
# max                   3,581.60                 4,064.30
#
# [8 rows x 22 columns]

# %%
# %%time
# Display the first few rows of the dataset
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857409 entries, 0 to 857408
# Data columns (total 28 columns):
# RowId                      857409 non-null int64
# IntersectionId             857409 non-null int64
# Latitude                   857409 non-null float64
# Longitude                  857409 non-null float64
# EntryStreetName            849220 non-null object
# ExitStreetName             851875 non-null object
# EntryHeading               857409 non-null object
# ExitHeading                857409 non-null object
# Hour                       857409 non-null int64
# Weekend                    857409 non-null int64
# Month                      857409 non-null int64
# Path                       857409 non-null object
# TotalTimeStopped_p20       857409 non-null int64
# TotalTimeStopped_p40       857409 non-null int64
# TotalTimeStopped_p50       857409 non-null int64
# TotalTimeStopped_p60       857409 non-null int64
# TotalTimeStopped_p80       857409 non-null int64
# TimeFromFirstStop_p20      857409 non-null int64
# TimeFromFirstStop_p40      857409 non-null int64
# TimeFromFirstStop_p50      857409 non-null int64
# TimeFromFirstStop_p60      857409 non-null int64
# TimeFromFirstStop_p80      857409 non-null int64
# DistanceToFirstStop_p20    857409 non-null float64
# DistanceToFirstStop_p40    857409 non-null float64
# DistanceToFirstStop_p50    857409 non-null float64
# DistanceToFirstStop_p60    857409 non-null float64
# DistanceToFirstStop_p80    857409 non-null float64
# City                       857409 non-null object
# dtypes: float64(7), int64(15), object(6)
# memory usage: 183.2+ MB
# Wall time: 189 ms

# %%
# %%time
# Display the first few rows of the dataset
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920335 entries, 0 to 1920334
# Data columns (total 13 columns):
# RowId              int64
# IntersectionId     int64
# Latitude           float64
# Longitude          float64
# EntryStreetName    object
# ExitStreetName     object
# EntryHeading       object
# ExitHeading        object
# Hour               int64
# Weekend            int64
# Month              int64
# Path               object
# City               object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 190.5+ MB
# Wall time: 2 ms

# %%
# %%time
def describe_categorical(df, sample_fields = 5):
    ''' Describe categoricals datasets, in more details to have ageneral idea of the values on each column '''
    text_variables = []
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df = df.select_dtypes(exclude = numerics)
    for col in df.columns:
        text_variables.append(col)
        pct_valid_data = 1 - (df[col].isnull().sum() / df.shape[0])
        unique_fields = list(set(df[col]))
        print('Variable Name: {:<18} % Data: {:0.2f} # Unique Fields:{:<6} Samples: {}'.format(col,pct_valid_data, len(unique_fields), unique_fields[:sample_fields]))
    return text_variables
# Out:
# Wall time: 0 ns

# %%
# %%time
# Load and utilize the describe_categorical funtion on the dataframe
categorical_feat = describe_categorical(train, 6)
# Out:
# Variable Name: EntryStreetName    % Data: 0.99 # Unique Fields:1708   Samples: [nan, 'South 67th Street', 'Lagrange Street', 'Brown Street', 'Bridge Street', 'North Kilpatrick Avenue']
# Variable Name: ExitStreetName     % Data: 0.99 # Unique Fields:1694   Samples: [nan, 'South 67th Street', 'Lagrange Street', 'Brown Street', 'Bridge Street', 'North Kilpatrick Avenue']
# Variable Name: EntryHeading       % Data: 1.00 # Unique Fields:8      Samples: ['SE', 'W', 'N', 'SW', 'E', 'S']
# Variable Name: ExitHeading        % Data: 1.00 # Unique Fields:8      Samples: ['SE', 'W', 'N', 'SW', 'E', 'S']
# Variable Name: Path               % Data: 1.00 # Unique Fields:15111  Samples: ['Plymouth Street_W_Hampshire Street_NW', 'North Beacon Street_NW_Soldiers Field Road_E', 'Lombard Street_W_South 17th Street_W', 'Milk Street_E_Milk Street_E', 'North Ashland Avenue_N_North Milwaukee Avenue_NW', 'Massachusetts Avenue_NW_Harrison Avenue_NE']
# Variable Name: City               % Data: 1.00 # Unique Fields:4      Samples: ['Philadelphia', 'Atlanta', 'Chicago', 'Boston']
# Wall time: 568 ms

# %%
# %%time
# Identify the unique EntryStreetName 
def encode_headings(df):
    '''Encode the heading of the streets'''
    directions_dict = {
        'N' : 0,
        'NE': 0.25,
        'E' : 0.5,
        'SE': 0.75,
        'S' : 1,
        'SW': 1.25,
        'W' : 1.5,
        'NW': 1.75
    }
    
    df['EntryHeadingCode'] = train['EntryHeading'].map(directions_dict)
    df['ExitHeadingCode'] = train['ExitHeading'].map(directions_dict)
    
    return df
# Out:
# Wall time: 0 ns

# %%
# %%time
# Apply the encode_headings function
train = encode_headings(train)
test = encode_headings(test)
# Out:
# Wall time: 263 ms

# %%
# %%time
# Identify the unique EntryStreetName 
def encode_streets(row):
    '''Encode the heading of the streets'''
    street_dict = {
        'Street'   : 0,
        'St'       : 0,
        'Avenue'   : 1,
        'Ave'      : 1,
        'Boulevard': 2,
        'Road'     : 3,
        'Drive'    : 4,
        'Lane'     : 5,
        'Tunnel'   : 6,
        'Highway'  : 7,
        'Way'      : 8,
        'Parkway'  : 9,
        'Parking'  : 10,
        'Oval'     : 11,
        'Square'   : 12,
        'Place'    : 13,
        'Bridge'   : 14
    }
    
    if pd.isna(row):
        return 0
    else:
        for road in street_dict.keys():
            if road in row:
                return street_dict[road]
    return 0
# Out:
# Wall time: 0 ns

# %%
# %%time
# Apply the encode_streets function to the train dataset
train['EntryStreetNameCode'] = train['EntryStreetName'].apply(encode_streets)
train['ExitStreetNameCode'] = train['ExitStreetName'].apply(encode_streets)

# Apply the encode_streets function to the test dataset
test['EntryStreetNameCode'] = test['EntryStreetName'].apply(encode_streets)
test['ExitStreetNameCode'] = test['ExitStreetName'].apply(encode_streets)
# Out:
# Wall time: 8.27 s

# %%
# %%time
# Identify the unique EntryStreetName 
def encode_city(df):
    '''Encode the heading of the streets'''
    city_dict = {
        'Chicago'      : 0,
        'Atlanta'      : 1,
        'Philadelphia' : 2,
        'Boston'       : 3,
    }

    df['CityCode'] = train['City'].map(city_dict)    
    return df
# Out:
# Wall time: 0 ns

# %%
# %%time
train = encode_city(train)
test = encode_city(test)
# Out:
# Wall time: 153 ms

# %%
# %%time
features = ['IntersectionId', 'Latitude', 'Longitude', 'Hour', 'Weekend',
            'Month', 'EntryHeadingCode', 'ExitHeadingCode', 'EntryStreetNameCode',
            'ExitStreetNameCode', 'CityCode']

categorical = ['Hour', 'Weekend', 'Month','EntryHeadingCode', 'ExitHeadingCode', 
               'EntryStreetNameCode', 'ExitStreetNameCode', 'CityCode']
# Out:
# Wall time: 0 ns

# %%
# %%time
target1 = train['TotalTimeStopped_p20']
target2 = train['TotalTimeStopped_p50']
target3 = train['TotalTimeStopped_p80']
target4 = train['DistanceToFirstStop_p20']
target5 = train['DistanceToFirstStop_p50']
target6 = train['DistanceToFirstStop_p80']
# Out:
# Wall time: 0 ns

# %%
# %%time
predictions = {1:[], 2:[], 3:[], 4:[], 5:[], 6:[]}
targets = [target1, target2, target3, target4, target5, target6]
# Out:
# Wall time: 1 ms

# %%
# %%time
# Hyper-Param Optimization Model...
train_data = lgb.Dataset(data = train[features], label = target3)

# Definition of the objective function...
def hyper_lgbm(num_leaves, feature_fraction, bagging_fraction, max_depth, min_split_gain, min_child_weight, lambda_l1, lambda_l2):
    params = {'application'     :'regression',
              'num_iterations'  : 450,
              'learning_rate'   : 0.02,
              'metric'          :'rmse'
             } # Default parameters configuration
    
    params["num_leaves"]       = int(round(num_leaves))
    params['feature_fraction'] = max(min(feature_fraction, 1), 0)
    params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
    params['max_depth']        = int(round(max_depth))
    params['min_split_gain']   = min_split_gain
    params['min_child_weight'] = min_child_weight
    params['lambda_l1']        = lambda_l1
    params['lambda_l2']        = lambda_l2
    
    cv_results = lgb.cv(params, train_data, nfold = 5, seed = 42, categorical_feature = categorical, stratified = False, verbose_eval = None)
    return -np.min(cv_results['rmse-mean'])
# Out:
# Wall time: 184 ms

# %%
# %%time
# Domain space -- Range of hyperparameters
param_domain_space = {'num_leaves'       :(120, 230),
                      'feature_fraction' :(0.3, 0.9),
                      'bagging_fraction' :(0.8, 1),
                      'lambda_l1'        :(0,3),
                      'lambda_l2'        :(0,5),
                      'max_depth'        :(8, 19),
                      'min_split_gain'   :(0.001, 0.1),
                      'min_child_weight' :(1, 20)
                     }
# Out:
# Wall time: 0 ns

# %%
# %%time
# Surrogate model
optimizer = BayesianOptimization(hyper_lgbm, param_domain_space, random_state = 42)

# Optimize
optimizer.maximize(init_points = 3, n_iter = 5)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | lambda_l2 | max_depth | min_ch... | min_sp... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        | -22.21    |  0.8749   |  0.8704   |  2.196    |  2.993    |  9.716    |  3.964    |  0.00675  |  215.3    |
# |  2        | -22.4     |  0.9202   |  0.7248   |  0.06175  |  4.85     |  17.16    |  5.034    |  0.019    |  140.2    |
# |  3        | -22.33    |  0.8608   |  0.6149   |  1.296    |  1.456    |  14.73    |  3.65     |  0.02992  |  160.3    |
# |  4        | -23.2     |  0.8      |  0.3      |  3.0      |  0.0      |  19.0     |  20.0     |  0.1      |  230.0    |
# |  5        | -23.29    |  1.0      |  0.9      |  0.0      |  5.0      |  8.0      |  20.0     |  0.001    |  187.4    |
# |  6        | -24.61    |  0.8      |  0.3      |  3.0      |  0.0      |  8.0      |  20.0     |  0.1      |  120.0    |
# |  7        | -22.46    |  1.0      |  0.9      |  0.0      |  5.0      |  10.68    |  1.0      |  0.001    |  150.0    |
# |  8        | -23.39    |  0.8      |  0.3      |  3.0      |  0.0      |  19.0     |  1.0      |  0.1      |  197.1    |
# =========================================================================================================================
# Wall time: 7min 40s

# %%
# %%time
optimizer.max
p = optimizer.max['params']
# Out:
# Wall time: 0 ns

# %%
# %%time
param = {'num_leaves'       : int(round(p['num_leaves'])),
         'feature_fraction' : p['feature_fraction'],
         'bagging_fraction' : p['bagging_fraction'],
         'max_depth'        : int(round(p['max_depth'])),
         'lambda_l1'        : p['lambda_l1'],
         'lambda_l2'        : p['lambda_l2'],
         'min_split_gain'   : p['min_split_gain'],
         'min_child_weight' : p['min_child_weight'],
         'learning_rate'    : 0.05,
         'objective'        : 'regression',
         'boosting_type'    : 'gbdt',
         'verbose'          : 1,
         'metric'           : 'rmse',
         'seed'             : 42,
        }
# Out:
# Wall time: 0 ns

# %%
# %%time
nfold = 3
kf = KFold(n_splits = nfold, random_state = 42, shuffle = True)

for i in range(len(predictions)):
    print('Training and predicting for target {}'.format(i+1))
    oof = np.zeros(len(train))
    predictions[i] = np.zeros(len(test))
    
    n = 1
    for train_index, valid_index in kf.split(targets[i]):
        print("fold {}".format(n))
        xg_train = lgb.Dataset(train[features].iloc[train_index], label = targets[i][train_index])
        xg_valid = lgb.Dataset(train[features].iloc[valid_index], label = targets[i][valid_index])   

        clf = lgb.train(param, xg_train, 15000, valid_sets = [xg_valid], categorical_feature = categorical, verbose_eval = 200, early_stopping_rounds = 500)
        oof[valid_index] = clf.predict(train[features].iloc[valid_index], num_iteration = clf.best_iteration) 

        predictions[i] += clf.predict(test[features], num_iteration = clf.best_iteration) / nfold
        n = n + 1
        
    print("\n\nCV RMSE: {:<0.4f}".format(np.sqrt(mean_squared_error(targets[i], oof))))
# Out:
# Training and predicting for target 1
# fold 1
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 6.39182
# [400]	valid_0's rmse: 6.21926
# [600]	valid_0's rmse: 6.14613
# [800]	valid_0's rmse: 6.10555
# [1000]	valid_0's rmse: 6.08477
# [1200]	valid_0's rmse: 6.06663
# [1400]	valid_0's rmse: 6.05288
# [1600]	valid_0's rmse: 6.04268
# [1800]	valid_0's rmse: 6.03606
# [2000]	valid_0's rmse: 6.03161
# [2200]	valid_0's rmse: 6.02711
# [2400]	valid_0's rmse: 6.02451
# [2600]	valid_0's rmse: 6.02323
# [2800]	valid_0's rmse: 6.02209
# [3000]	valid_0's rmse: 6.02301
# [3200]	valid_0's rmse: 6.02467
# Early stopping, best iteration is:
# [2789]	valid_0's rmse: 6.02205
# fold 2
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 6.2613
# [400]	valid_0's rmse: 6.10211
# [600]	valid_0's rmse: 6.03839
# [800]	valid_0's rmse: 5.99869
# [1000]	valid_0's rmse: 5.97383
# [1200]	valid_0's rmse: 5.95818
# [1400]	valid_0's rmse: 5.94751
# [1600]	valid_0's rmse: 5.94191
# [1800]	valid_0's rmse: 5.93309
# [2000]	valid_0's rmse: 5.93014
# [2200]	valid_0's rmse: 5.92873
# [2400]	valid_0's rmse: 5.92851
# [2600]	valid_0's rmse: 5.92844
# [2800]	valid_0's rmse: 5.92876
# Early stopping, best iteration is:
# [2359]	valid_0's rmse: 5.92791
# fold 3
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 6.23397
# [400]	valid_0's rmse: 6.06904
# [600]	valid_0's rmse: 6.00045
# [800]	valid_0's rmse: 5.96314
# [1000]	valid_0's rmse: 5.9352
# [1200]	valid_0's rmse: 5.91748
# [1400]	valid_0's rmse: 5.90346
# [1600]	valid_0's rmse: 5.89745
# [1800]	valid_0's rmse: 5.89108
# [2000]	valid_0's rmse: 5.88977
# [2200]	valid_0's rmse: 5.88638
# [2400]	valid_0's rmse: 5.88578
# [2600]	valid_0's rmse: 5.88585
# [2800]	valid_0's rmse: 5.88462
# [3000]	valid_0's rmse: 5.8852
# [3200]	valid_0's rmse: 5.88572
# Early stopping, best iteration is:
# [2758]	valid_0's rmse: 5.88426
#
#
# CV RMSE: 5.9450
# Training and predicting for target 2
# fold 1
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 12.5904
# [400]	valid_0's rmse: 11.8995
# [600]	valid_0's rmse: 11.6115
# [800]	valid_0's rmse: 11.4274
# [1000]	valid_0's rmse: 11.307
# [1200]	valid_0's rmse: 11.215
# [1400]	valid_0's rmse: 11.1546
# [1600]	valid_0's rmse: 11.1081
# [1800]	valid_0's rmse: 11.0679
# [2000]	valid_0's rmse: 11.0417
# [2200]	valid_0's rmse: 11.0208
# [2400]	valid_0's rmse: 10.9956
# [2600]	valid_0's rmse: 10.9801
# [2800]	valid_0's rmse: 10.9664
# [3000]	valid_0's rmse: 10.9534
# [3200]	valid_0's rmse: 10.9456
# [3400]	valid_0's rmse: 10.9383
# [3600]	valid_0's rmse: 10.9361
# [3800]	valid_0's rmse: 10.9311
# [4000]	valid_0's rmse: 10.9274
# [4200]	valid_0's rmse: 10.9274
# [4400]	valid_0's rmse: 10.9247
# [4600]	valid_0's rmse: 10.9254
# [4800]	valid_0's rmse: 10.9249
# [5000]	valid_0's rmse: 10.9257
# Early stopping, best iteration is:
# [4506]	valid_0's rmse: 10.924
# fold 2
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 12.4814
# [400]	valid_0's rmse: 11.8243
# [600]	valid_0's rmse: 11.5396
# [800]	valid_0's rmse: 11.37
# [1000]	valid_0's rmse: 11.256
# [1200]	valid_0's rmse: 11.1688
# [1400]	valid_0's rmse: 11.1114
# [1600]	valid_0's rmse: 11.0635
# [1800]	valid_0's rmse: 11.0261
# [2000]	valid_0's rmse: 11.0045
# [2200]	valid_0's rmse: 10.9865
# [2400]	valid_0's rmse: 10.9684
# [2600]	valid_0's rmse: 10.9522
# [2800]	valid_0's rmse: 10.9372
# [3000]	valid_0's rmse: 10.9242
# [3200]	valid_0's rmse: 10.915
# [3400]	valid_0's rmse: 10.9121
# [3600]	valid_0's rmse: 10.9084
# [3800]	valid_0's rmse: 10.907
# [4000]	valid_0's rmse: 10.9041
# [4200]	valid_0's rmse: 10.9033
# [4400]	valid_0's rmse: 10.9026
# [4600]	valid_0's rmse: 10.9044
# [4800]	valid_0's rmse: 10.9027
# Early stopping, best iteration is:
# [4408]	valid_0's rmse: 10.9021
# fold 3
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 12.6479
# [400]	valid_0's rmse: 11.9367
# [600]	valid_0's rmse: 11.6128
# [800]	valid_0's rmse: 11.4472
# [1000]	valid_0's rmse: 11.3014
# [1200]	valid_0's rmse: 11.1921
# [1400]	valid_0's rmse: 11.1291
# [1600]	valid_0's rmse: 11.0788
# [1800]	valid_0's rmse: 11.0408
# [2000]	valid_0's rmse: 11.0158
# [2200]	valid_0's rmse: 10.9903
# [2400]	valid_0's rmse: 10.9663
# [2600]	valid_0's rmse: 10.9519
# [2800]	valid_0's rmse: 10.9378
# [3000]	valid_0's rmse: 10.9246
# [3200]	valid_0's rmse: 10.9154
# [3400]	valid_0's rmse: 10.9074
# [3600]	valid_0's rmse: 10.9026
# [3800]	valid_0's rmse: 10.901
# [4000]	valid_0's rmse: 10.8997
# [4200]	valid_0's rmse: 10.8989
# [4400]	valid_0's rmse: 10.8969
# [4600]	valid_0's rmse: 10.8968
# [4800]	valid_0's rmse: 10.8971
# [5000]	valid_0's rmse: 10.8977
# [5200]	valid_0's rmse: 10.8985
# Early stopping, best iteration is:
# [4884]	valid_0's rmse: 10.8962
#
#
# CV RMSE: 10.9075
# Training and predicting for target 3
# fold 1
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 22.0717
# [400]	valid_0's rmse: 20.6588
# [600]	valid_0's rmse: 20.0922
# [800]	valid_0's rmse: 19.6875
# [1000]	valid_0's rmse: 19.4253
# [1200]	valid_0's rmse: 19.238
# [1400]	valid_0's rmse: 19.0937
# [1600]	valid_0's rmse: 18.9808
# [1800]	valid_0's rmse: 18.8951
# [2000]	valid_0's rmse: 18.836
# [2200]	valid_0's rmse: 18.7856
# [2400]	valid_0's rmse: 18.7432
# [2600]	valid_0's rmse: 18.713
# [2800]	valid_0's rmse: 18.6781
# [3000]	valid_0's rmse: 18.6535
# [3200]	valid_0's rmse: 18.6316
# [3400]	valid_0's rmse: 18.6167
# [3600]	valid_0's rmse: 18.6076
# [3800]	valid_0's rmse: 18.6001
# [4000]	valid_0's rmse: 18.5928
# [4200]	valid_0's rmse: 18.5848
# [4400]	valid_0's rmse: 18.5809
# [4600]	valid_0's rmse: 18.5757
# [4800]	valid_0's rmse: 18.5747
# [5000]	valid_0's rmse: 18.5675
# [5200]	valid_0's rmse: 18.5666
# [5400]	valid_0's rmse: 18.5677
# [5600]	valid_0's rmse: 18.5677
# Early stopping, best iteration is:
# [5112]	valid_0's rmse: 18.5655
# fold 2
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 21.9953
# [400]	valid_0's rmse: 20.664
# [600]	valid_0's rmse: 20.0763
# [800]	valid_0's rmse: 19.7083
# [1000]	valid_0's rmse: 19.4439
# [1200]	valid_0's rmse: 19.2537
# [1400]	valid_0's rmse: 19.1245
# [1600]	valid_0's rmse: 19.0286
# [1800]	valid_0's rmse: 18.9506
# [2000]	valid_0's rmse: 18.8857
# [2200]	valid_0's rmse: 18.8424
# [2400]	valid_0's rmse: 18.7966
# [2600]	valid_0's rmse: 18.7605
# [2800]	valid_0's rmse: 18.7247
# [3000]	valid_0's rmse: 18.7013
# [3200]	valid_0's rmse: 18.6846
# [3400]	valid_0's rmse: 18.6625
# [3600]	valid_0's rmse: 18.649
# [3800]	valid_0's rmse: 18.6362
# [4000]	valid_0's rmse: 18.6306
# [4200]	valid_0's rmse: 18.6263
# [4400]	valid_0's rmse: 18.6192
# [4600]	valid_0's rmse: 18.6178
# [4800]	valid_0's rmse: 18.6127
# [5000]	valid_0's rmse: 18.6099
# [5200]	valid_0's rmse: 18.6133
# [5400]	valid_0's rmse: 18.6122
# Early stopping, best iteration is:
# [4989]	valid_0's rmse: 18.6093
# fold 3
# Training until validation scores don't improve for 500 rounds
# [200]	valid_0's rmse: 22.1235
# [400]	valid_0's rmse: 20.7718
# [600]	valid_0's rmse: 20.1169
# [800]	valid_0's rmse: 19.7322
# [1000]	valid_0's rmse: 19.4776
# [1200]	valid_0's rmse: 19.2998
# [1400]	valid_0's rmse: 19.1724
# [1600]	valid_0's rmse: 19.0771
# [1800]	valid_0's rmse: 18.9749
# [2000]	valid_0's rmse: 18.9047
# [2200]	valid_0's rmse: 18.8499
# [2400]	valid_0's rmse: 18.8065
# [2600]	valid_0's rmse: 18.7742
# [2800]	valid_0's rmse: 18.7424
# [3000]	valid_0's rmse: 18.7215
# [3200]	valid_0's rmse: 18.7023
# [3400]	valid_0's rmse: 18.6859
# [3600]	valid_0's rmse: 18.6742
# [3800]	valid_0's rmse: 18.6675
# [4000]	valid_0's rmse: 18.6562
# [4200]	valid_0's rmse: 18.6516
# [4400]	valid_0's rmse: 18.6433
# [4600]	valid_0's rmse: 18.6369
# [4800]	valid_0's rmse: 18.6335
# [5000]	valid_0's rmse: 18.6276
# [5200]	valid_0's rmse: 18.6257
# [5400]	valid_0's rmse: 18.6233
# [5600]	valid_0's rmse: 18.625
# [5800]	valid_0's rmse: 18.6292
# Early stopping, best iteration is:
# [5410]	valid_0's rmse: 18.6232
